# %% [markdown]
# # roda os graficos de history pra todos

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
for filename in os.listdir('logy'):
    print(filename)
    for cont in range(5):
        print(cont)
        if os.path.exists('logy/'+filename+'/'+str(cont)+'/Loss'):
            event_loss = EventAccumulator('logy/'+filename+'/'+str(cont)+'/Loss/val_loss')
            event_loss.Reload()
            event_train_loss = EventAccumulator('logy/'+filename+'/'+str(cont)+'/Loss/train_loss')
            event_train_loss.Reload()
            w_times, step_nums, valloss = zip(*event_loss.Scalars('Loss'))
            w_times, step_nums, trainloss = zip(*event_train_loss.Scalars('Loss'))

            plt.plot(valloss)
            plt.plot(trainloss)
            # plt.plot(valsacc)
            # plt.plot(trainacc)
            plt.title(filename + ' Loss')
            plt.ylabel('Loss')
            plt.xlabel('epoch')
            plt.legend(['val_loss', 'train_loss','val_acc', 'train_acc'], loc='upper left')
            plt.savefig('logy/'+filename+'/history_'+filename+'_fold'+str(cont)+'.png')
            plt.show()
# Out:
# Single_Gender_v4
# 0
# 2022-03-21 18:07:22.588997: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-21 18:07:22.589018: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 1
# 2
# 3
# 4
# Single_PMAT_v2
# 0
# 1
# 2
# 3
# 4
# Single_MMSE_Score_v2
# 0
# 1
# 2
# 3
# 4
# Single_PMAT_v1
# 0
# 1
# 2
# 3
# 4
# Single_MMSE_Score_v3
# 0
# 1
# 2
# 3
# 4
# Single_Gender_v3
# 0
# 1
# 2
# 3
# 4
# Single_Gender_v1
# 0
# 1
# 2
# 3
# 4
# Single_Gender_v2
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # roda os graficos de history especifico

# %%
filename = 'hard_middle_SHARED_CWEIGHT_HCP_MTL_PMAT24_A_CR_MMSE_Score_Gender_v1'
for cont in range(5):
    print(cont)
    if os.path.exists('logy/'+filename+'/'+str(cont)+'/Loss'):
        event_loss = EventAccumulator('logy/'+filename+'/'+str(cont)+'/Loss/val_loss')
        event_loss.Reload()
        event_train_loss = EventAccumulator('logy/'+filename+'/'+str(cont)+'/Loss/train_loss')
        event_train_loss.Reload()
        w_times, step_nums, valloss = zip(*event_loss.Scalars('Loss'))
        w_times, step_nums, trainloss = zip(*event_train_loss.Scalars('Loss'))

        plt.plot(valloss)
        plt.plot(trainloss)
        # plt.plot(valsacc)
        # plt.plot(trainacc)
        plt.title(filename + ' Loss')
        plt.ylabel('Loss')
        plt.xlabel('epoch')
        plt.legend(['val_loss', 'train_loss','val_acc', 'train_acc'], loc='upper left')
        plt.savefig('logy/'+filename+'/history_'+filename+'_fold'+str(cont)+'.png')
        plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
